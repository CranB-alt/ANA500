# %%
a = 3
a
# Out:
# 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#C:\Users\oknuy\OneDrive\Documents\National University\ANA 500 Sep 29
url = r"/Users/oknuy/OneDrive/Documents/National University/ANA 500 Sep 29/adult_income.csv"

# %%
df = pd.read_csv(url)

# %%
df.head(100)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# ..  ...               ...     ...           ...            ...
# 95   29         Local-gov  115585  Some-college             10
# 96   48  Self-emp-not-inc  191277     Doctorate             16
# 97   37           Private  202683  Some-college             10
# 98   48           Private  171095    Assoc-acdm             12
# 99   32       Federal-gov  249409       HS-grad              9
#
#         marital-status         occupation   relationship   race     sex  \
# 0        Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.read(relationship)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\1074198280.py in ?()
# ----> 1 df.read(relationship)
#
# ~\anaconda3\Navigator\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
df.duplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\1503988213.py in ?()
# ----> 1 df.duplicates()
#
# ~\anaconda3\Navigator\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 4881    25           Private  308144     Bachelors             13
# 5104    90           Private   52386  Some-college             10
# 9171    21           Private  250051  Some-college             10
# 11631   20           Private  107658  Some-college             10
# 13084   25           Private  195994       1st-4th              2
# 15059   21           Private  243368     Preschool              1
# 17040   46           Private  173243       HS-grad              9
# 18555   30           Private  144593       HS-grad              9
# 18698   19           Private   97261       HS-grad              9
# 21318   19           Private  138153  Some-college             10
# 21490   19           Private  146679  Some-college             10
# 21875   49           Private   31267       7th-8th              4
# 22300   25           Private  195994       1st-4th              2
# ...

# %%
df[df['column'] > 50000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df[df['column'] > 50000]
#
# ...

# %%
df[df < 50000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df[df < 50000]
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\frame.py:7900, in DataFrame._cmp_method(self, other, op)
#    7897 self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7899 # See GH#4537 for discussion of scalar op behavior
# ...

# %%
filtered_df = df[df['category'] < 50000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 filtered_df = df[df['category'] < 50000]
#
# ...

# %%
df[df['column'] > 50000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df[df['column'] > 50000]
#
# ...

# %%
df[df['income'] > 50000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df[df['income'] > 50000]
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[df['income'] >=50K]
# Out:
#   Cell In[44], line 1
#     df[df['income'] >=50K]
#                        ^
# SyntaxError: invalid decimal literal

# %%
print (df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
print (df.income)
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 32556    <=50K
# 32557     >50K
# 32558    <=50K
# 32559    <=50K
# 32560     >50K
# Name: income, Length: 32561, dtype: object

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df[df['income'] > 50000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df[df['income'] > 50000]
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
# Remove 'k', convert to float, then multiply by 1000
df['income'] = df['income'].str.lower().str.replace('<=50K', '', regex=False).astype(float) * 1000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Remove 'k', convert to float, then multiply by 1000
# ----> 2 df['income'] = df['income'].str.lower().str.replace('<=50K', '', regex=False).astype(float) * 1000
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df['income'] = df['income'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['income'] = df['income'].astype(int)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df[['education', 'education-num']].drop_duplicates().sort_values('education-num')
# Out:
#         education  education-num
# 224     Preschool              1
# 160       1st-4th              2
# 56        5th-6th              3
# 15        7th-8th              4
# 6             9th              5
# 77           10th              6
# 3            11th              7
# 415          12th              8
# 2         HS-grad              9
# 10   Some-college             10
# 14      Assoc-voc             11
# 13     Assoc-acdm             12
# 0       Bachelors             13
# 5         Masters             14
# 52    Prof-school             15
# 20      Doctorate             16

# %%
df[['education', 'education-num', 'income']].drop_duplicates().sort_values('education-num')
# Out:
#          education  education-num income
# 224      Preschool              1  <=50K
# 160        1st-4th              2  <=50K
# 2817       1st-4th              2   >50K
# 56         5th-6th              3  <=50K
# 2159       5th-6th              3   >50K
# 15         7th-8th              4  <=50K
# 183        7th-8th              4   >50K
# 6              9th              5  <=50K
# 2003           9th              5   >50K
# 77            10th              6  <=50K
# 588           10th              6   >50K
# 3             11th              7  <=50K
# 729           11th              7   >50K
# 415           12th              8   >50K
# 484           12th              8  <=50K
# 7          HS-grad              9   >50K
# 2          HS-grad              9  <=50K
# 10    Some-college             10   >50K
# 31    Some-college             10  <=50K
# 14       Assoc-voc             11   >50K
# 48       Assoc-voc             11  <=50K
# 127     Assoc-acdm             12   >50K
# ...

# %%
# Identify columns that contain '?' in any row
columns_with_question_mark = [col for col in df.columns if df[col].astype(str).str.contains('\?').any()]

print("Columns containing '?':", columns_with_question_mark)
# Out:
# Columns containing '?': ['workclass', 'occupation', 'native-country']

# %%
df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 14      40   Private  121772     Assoc-voc             11
# 27      54         ?  180211  Some-college             10
# 38      31   Private   84154  Some-college             10
# 51      18   Private  226956       HS-grad              9
# 61      32         ?  293936       7th-8th              4
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors             13
# 32531   30         ?   33811     Bachelors             13
# 32539   71         ?  287372     Doctorate             16
# 32541   41         ?  202822       HS-grad              9
# 32542   72         ?  129912       HS-grad              9
#
#               marital-status     occupation   relationship  \
# 14        Married-civ-spouse   Craft-repair        Husband
# 27        Married-civ-spouse              ?        Husband
# 38        Married-civ-spouse          Sales        Husband
# ...

# %%
df[['native country', 'income']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df[['native country', 'income']]
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
df[['native-country', 'income']]
# Out:
#       native-country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 32556  United-States  <=50K
# 32557  United-States   >50K
# 32558  United-States  <=50K
# 32559  United-States  <=50K
# 32560  United-States   >50K
#
# [32561 rows x 2 columns]

# %%
# Group by native-country and calculate average income
highest_income_country = df.groupby('native-country')['income'].mean().sort_values(ascending=False)

# Display the top result
print("Country with highest average income:")
print(highest_income_country.head(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Navigator\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
# Display only the 'education' and 'income' columns
selected_columns = df[['education', 'income']]
print(selected_columns.head())
# Out:
#    education income
# 0  Bachelors  <=50K
# 1  Bachelors  <=50K
# 2    HS-grad  <=50K
# 3       11th  <=50K
# 4  Bachelors  <=50K

# %%
# Display only the 'education' and 'income' columns
selected_columns = df[['education', 'income']]
print(selected_columns.head(10))
# Out:
#    education income
# 0  Bachelors  <=50K
# 1  Bachelors  <=50K
# 2    HS-grad  <=50K
# 3       11th  <=50K
# 4  Bachelors  <=50K
# 5    Masters  <=50K
# 6        9th  <=50K
# 7    HS-grad   >50K
# 8    Masters   >50K
# 9  Bachelors   >50K

# %%
# Display only the 'education' and 'income' columns
selected_columns = df[['education', 'income']]
print(selected_columns.head(20))
# Out:
#        education income
# 0      Bachelors  <=50K
# 1      Bachelors  <=50K
# 2        HS-grad  <=50K
# 3           11th  <=50K
# 4      Bachelors  <=50K
# 5        Masters  <=50K
# 6            9th  <=50K
# 7        HS-grad   >50K
# 8        Masters   >50K
# 9      Bachelors   >50K
# 10  Some-college   >50K
# 11     Bachelors   >50K
# 12     Bachelors  <=50K
# 13    Assoc-acdm  <=50K
# 14     Assoc-voc   >50K
# 15       7th-8th  <=50K
# 16       HS-grad  <=50K
# 17       HS-grad  <=50K
# 18          11th  <=50K
# 19       Masters   >50K

# %%
# Display only the 'education' and 'income' columns
selected_columns = df[['education', 'income']]
print(selected_columns.head(30))
# Out:
#        education income
# 0      Bachelors  <=50K
# 1      Bachelors  <=50K
# 2        HS-grad  <=50K
# 3           11th  <=50K
# 4      Bachelors  <=50K
# 5        Masters  <=50K
# 6            9th  <=50K
# 7        HS-grad   >50K
# 8        Masters   >50K
# 9      Bachelors   >50K
# 10  Some-college   >50K
# 11     Bachelors   >50K
# 12     Bachelors  <=50K
# 13    Assoc-acdm  <=50K
# 14     Assoc-voc   >50K
# 15       7th-8th  <=50K
# 16       HS-grad  <=50K
# 17       HS-grad  <=50K
# 18          11th  <=50K
# 19       Masters   >50K
# 20     Doctorate   >50K
# 21       HS-grad  <=50K
# 22           9th  <=50K
# 23          11th  <=50K
# 24       HS-grad  <=50K
# 25     Bachelors   >50K
# 26       HS-grad  <=50K
# 27  Some-college   >50K
# 28       HS-grad  <=50K
# 29       HS-grad  <=50K

# %%
# Display only the 'marital-status' and 'income' columns
selected_columns = df[['marital-status', 'income']]
print(selected_columns.head(20))
# Out:
#            marital-status income
# 0           Never-married  <=50K
# 1      Married-civ-spouse  <=50K
# 2                Divorced  <=50K
# 3      Married-civ-spouse  <=50K
# 4      Married-civ-spouse  <=50K
# 5      Married-civ-spouse  <=50K
# 6   Married-spouse-absent  <=50K
# 7      Married-civ-spouse   >50K
# 8           Never-married   >50K
# 9      Married-civ-spouse   >50K
# 10     Married-civ-spouse   >50K
# 11     Married-civ-spouse   >50K
# 12          Never-married  <=50K
# 13          Never-married  <=50K
# 14     Married-civ-spouse   >50K
# 15     Married-civ-spouse  <=50K
# 16          Never-married  <=50K
# 17          Never-married  <=50K
# 18     Married-civ-spouse  <=50K
# 19               Divorced   >50K

# %%
# Display only the 'marital-status' and 'income' columns
selected_columns = df[['marital-status', 'income']]
print(selected_columns.head(25))
# Out:
#            marital-status income
# 0           Never-married  <=50K
# 1      Married-civ-spouse  <=50K
# 2                Divorced  <=50K
# 3      Married-civ-spouse  <=50K
# 4      Married-civ-spouse  <=50K
# 5      Married-civ-spouse  <=50K
# 6   Married-spouse-absent  <=50K
# 7      Married-civ-spouse   >50K
# 8           Never-married   >50K
# 9      Married-civ-spouse   >50K
# 10     Married-civ-spouse   >50K
# 11     Married-civ-spouse   >50K
# 12          Never-married  <=50K
# 13          Never-married  <=50K
# 14     Married-civ-spouse   >50K
# 15     Married-civ-spouse  <=50K
# 16          Never-married  <=50K
# 17          Never-married  <=50K
# 18     Married-civ-spouse  <=50K
# 19               Divorced   >50K
# 20     Married-civ-spouse   >50K
# 21              Separated  <=50K
# 22     Married-civ-spouse  <=50K
# 23     Married-civ-spouse  <=50K
# 24               Divorced  <=50K

# %%
# Display only the 'marital-status' and 'income' columns
selected_columns = df[['marital-status', 'income']]
print(selected_columns.head(50))
# Out:
#            marital-status income
# 0           Never-married  <=50K
# 1      Married-civ-spouse  <=50K
# 2                Divorced  <=50K
# 3      Married-civ-spouse  <=50K
# 4      Married-civ-spouse  <=50K
# 5      Married-civ-spouse  <=50K
# 6   Married-spouse-absent  <=50K
# 7      Married-civ-spouse   >50K
# 8           Never-married   >50K
# 9      Married-civ-spouse   >50K
# 10     Married-civ-spouse   >50K
# 11     Married-civ-spouse   >50K
# 12          Never-married  <=50K
# 13          Never-married  <=50K
# 14     Married-civ-spouse   >50K
# 15     Married-civ-spouse  <=50K
# 16          Never-married  <=50K
# 17          Never-married  <=50K
# 18     Married-civ-spouse  <=50K
# 19               Divorced   >50K
# 20     Married-civ-spouse   >50K
# 21              Separated  <=50K
# 22     Married-civ-spouse  <=50K
# 23     Married-civ-spouse  <=50K
# 24               Divorced  <=50K
# 25     Married-civ-spouse   >50K
# 26          Never-married  <=50K
# ...

# %%
# Filter for HS-grad and count by income level
hs_grad_income_counts = df[df['education'] == 'HS-grad']['income'].value_counts()

print("Number of individuals with HS-grad by income level:")
print(hs_grad_income_counts)
# Out:
# Number of individuals with HS-grad by income level:
# income
# <=50K    8826
# >50K     1675
# Name: count, dtype: int64

# %%
# Select and display 'education-num' and 'income' columns
education_income = df[['education-num', 'income']]
print(education_income.head())  # Shows the first few rows

# Optional: Get unique combinations and their counts
combo_counts = education_income.value_counts().reset_index(name='count')
print("\nUnique combinations of education-num and income:")
print(combo_counts)
# Out:
#    education-num income
# 0             13  <=50K
# 1             13  <=50K
# 2              9  <=50K
# 3              7  <=50K
# 4             13  <=50K
#
# Unique combinations of education-num and income:
#     education-num income  count
# 0               9  <=50K   8826
# 1              10  <=50K   5904
# 2              13  <=50K   3134
# 3              13   >50K   2221
# 4               9   >50K   1675
# 5              10   >50K   1387
# 6               7  <=50K   1115
# 7              11  <=50K   1021
# 8              14   >50K    959
# 9               6  <=50K    871
# 10             12  <=50K    802
# 11             14  <=50K    764
# 12              4  <=50K    606
# 13              5  <=50K    487
# 14             15   >50K    423
# 15              8  <=50K    400
# 16             11   >50K    361
# 17              3  <=50K    317
# 18             16   >50K    306
# 19             12   >50K    265
# 20              2  <=50K    162
# 21             15  <=50K    153
# ...

# %%
# Filter for high income
high_income = df[df['income'] == '>50K']

# Calculate the proportion of high-income earners per education level
income_ratio = (
    high_income['education'].value_counts()
    .div(df['education'].value_counts())
    .sort_values(ascending=False)
)

# Display the education level with the highest proportion of high-income earners
top_education = income_ratio.idxmax()
top_ratio = income_ratio.max()

print(f"The education level with the highest proportion of high-income earners is: {top_education} ({top_ratio:.2%})")
# Out:
# The education level with the highest proportion of high-income earners is: Doctorate (74.09%)
